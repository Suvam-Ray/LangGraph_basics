# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver
# Out:
# c:\Users\suvam.ray\miniconda3\Lib\site-packages\langgraph\cache\base\__init__.py:8: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
load_dotenv()

llm = ChatGroq(model="llama-3.3-70b-versatile")

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.',
#  'explanation': 'This joke is a play on words, using the multiple meanings of the word "crusty" to create a pun. \n\nIn one sense, a pizza has a crust, which is the outer layer of the bread. However, "crusty" can also be used to describe someone who is irritable, gruff, or in a bad mood. \n\nThe joke relies on this double meaning, setting up the expectation that the pizza is in a bad mood, and then subverting it with a clever wordplay. The punchline "it was feeling a little crusty" is funny because it references both the pizza\'s crust and its bad mood, creating a clever and amusing connection between the two. The humor comes from the unexpected twist on the word\'s meaning, making it a lighthearted and cheesy (no pun intended) joke.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is a play on words, using the multiple meanings of the word "crusty" to create a pun. \n\nIn one sense, a pizza has a crust, which is the outer layer of the bread. However, "crusty" can also be used to describe someone who is irritable, gruff, or in a bad mood. \n\nThe joke relies on this double meaning, setting up the expectation that the pizza is in a bad mood, and then subverting it with a clever wordplay. The punchline "it was feeling a little crusty" is funny because it references both the pizza\'s crust and its bad mood, creating a clever and amusing connection between the two. The humor comes from the unexpected twist on the word\'s meaning, making it a lighthearted and cheesy (no pun intended) joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f15760c-d39a-6ee2-8002-1abd9b1bef
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is a play on words, using the multiple meanings of the word "crusty" to create a pun. \n\nIn one sense, a pizza has a crust, which is the outer layer of the bread. However, "crusty" can also be used to describe someone who is irritable, gruff, or in a bad mood. \n\nThe joke relies on this double meaning, setting up the expectation that the pizza is in a bad mood, and then subverting it with a clever wordplay. The punchline "it was feeling a little crusty" is funny because it references both the pizza\'s crust and its bad mood, creating a clever and amusing connection between the two. The humor comes from the unexpected twist on the word\'s meaning, making it a lighthearted and cheesy (no pun intended) joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f15760c-d39a-6ee2-8002-1abd9b1be
# ...

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti refuse to get married?\n\nBecause it was afraid of getting tangled up in a lifelong commitment.',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is a play on words, using the multiple meanings of the word "crusty" to create a pun. \n\nIn one sense, a pizza has a crust, which is the outer layer of the bread. However, "crusty" can also be used to describe someone who is irritable, gruff, or in a bad mood. \n\nThe joke relies on this double meaning, setting up the expectation that the pizza is in a bad mood, and then subverting it with a clever wordplay. The punchline "it was feeling a little crusty" is funny because it references both the pizza\'s crust and its bad mood, creating a clever and amusing connection between the two. The humor comes from the unexpected twist on the word\'s meaning, making it a lighthearted and cheesy (no pun intended) joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f15760c-d39a-6ee2-8002-1abd9b1bef
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is a play on words, using the multiple meanings of the word "crusty" to create a pun. \n\nIn one sense, a pizza has a crust, which is the outer layer of the bread. However, "crusty" can also be used to describe someone who is irritable, gruff, or in a bad mood. \n\nThe joke relies on this double meaning, setting up the expectation that the pizza is in a bad mood, and then subverting it with a clever wordplay. The punchline "it was feeling a little crusty" is funny because it references both the pizza\'s crust and its bad mood, creating a clever and amusing connection between the two. The humor comes from the unexpected twist on the word\'s meaning, making it a lighthearted and cheesy (no pun intended) joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f15760c-d39a-6ee2-8002-1abd9b1be
# ...

# %% [markdown]
# ### Time Travel

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f15760c-cbc8-62aa-8000-f2d715ad30dd"}})
# Out:
# StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f15760c-cbc8-62aa-8000-f2d715ad30dd'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-05-24T11:07:48.857907+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f15760c-cbc4-6e21-bfff-d7e2eca0da87'}}, tasks=(PregelTask(id='6d270ad4-bd05-e535-fac6-1ab6f0508619', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.'}),), interrupts=())

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f15760c-cbc8-62aa-8000-f2d715ad30dd"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.',
#  'explanation': 'This joke is a play on words, using a pun to create humor. The phrase "feeling a little crusty" has a double meaning here. \n\nIn one sense, "crusty" can refer to the outer layer of a pizza, which is typically crunchy and crispy. However, "feeling crusty" is also an idiomatic expression that means being irritable, grouchy, or in a bad mood. \n\nThe joke relies on this wordplay to create a clever connection between the characteristics of a pizza (having a crust) and the emotional state of being in a bad mood (feeling crusty). The punchline is humorous because it takes a common phrase and gives it a literal twist, creating a unexpected and clever connection between the setup and the punchline.'}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is a play on words, using a pun to create humor. The phrase "feeling a little crusty" has a double meaning here. \n\nIn one sense, "crusty" can refer to the outer layer of a pizza, which is typically crunchy and crispy. However, "feeling crusty" is also an idiomatic expression that means being irritable, grouchy, or in a bad mood. \n\nThe joke relies on this wordplay to create a clever connection between the characteristics of a pizza (having a crust) and the emotional state of being in a bad mood (feeling crusty). The punchline is humorous because it takes a common phrase and gives it a literal twist, creating a unexpected and clever connection between the setup and the punchline.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f157611-f600-6fdc-8003-823affe4c2a3'}}, metadata={'source'
# ...

# %% [markdown]
# #### Updating State

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "bf79ec5a-cbd2-4d56-9d0c-6865a7cfbd06", "checkpoint_ns": ""}}, {'topic':'air fryer'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f157614-7337-6f0d-8000-0a04b3079b00'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'air fryer'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f157614-7337-6f0d-8000-0a04b3079b00'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2026-05-24T11:11:14.319732+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': 'bf79ec5a-cbd2-4d56-9d0c-6865a7cfbd06'}}, tasks=(PregelTask(id='e6830bc8-fa77-89e3-f410-28d0886818e0', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f157614-7337-6f0d-8000-0a04b3079b00"}})
# Out:
# {'topic': 'air fryer',
#  'joke': 'Why did the air fryer go to therapy?\n\nBecause it was feeling a little "fried" under the pressure to always produce crispy results.',
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'air fryer', 'joke': 'Why did the air fryer go to therapy?\n\nBecause it was feeling a little "fried" under the pressure to always produce crispy results.', 'explanation': 'This joke is a play on words, using the phrase "feeling a little fried" in a punny way. In everyday language, "feeling fried" is an idiomatic expression that means feeling overwhelmed, stressed, or exhausted. However, in the context of an air fryer, "fried" has a literal meaning, as it is an appliance designed to fry food.\n\nThe joke relies on this double meaning to create humor. The air fryer, which is normally responsible for making food crispy, is now "feeling a little fried" itself, implying that it\'s struggling to cope with the pressure to always produce perfect results. This unexpected twist on the usual meaning of "fried" creates a comedic effect, as it\'s unusual to think of an appliance having feelings or emotional struggles.\n\nThe added layer of wordplay is what makes t
# ...

# %% [markdown]
# ### Fault Tolerance

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import time

# %%
# 1. Define the state
class CrashState(TypedDict):
    input: str
    step1: str
    step2: str

# %%
# 2. Define steps
def step_1(state: CrashState) -> CrashState:
    print("✅ Step 1 executed")
    return {"step1": "done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print("⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(1000)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print("✅ Step 3 executed")
    return {"done": True}

# %%
# 3. Build the graph
builder = StateGraph(CrashState)
builder.add_node("step_1", step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
try:
    print("▶️ Running graph: Please manually interrupt during Step 2...")
    graph.invoke({"input": "start"}, config={"configurable": {"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print("❌ Kernel manually interrupted (crash simulated).")
# Out:
# ▶️ Running graph: Please manually interrupt during Step 2...
# ✅ Step 1 executed
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)

# %%
# 6. Re-run to show fault-tolerant resume
print("\n🔁 Re-running the graph to demonstrate fault tolerance...")
final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}})
print("\n✅ Final State:", final_state)

# %%
list(graph.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
